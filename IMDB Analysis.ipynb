# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data =  pd.read_csv(r"C:\Users\mahal\Downloads\archive (2)\Top 1000 IMDB movies (1).csv")

# %%
data.head()
# Out:
#    Unnamed: 0                                     Movie Name Year of Release  \
# 0           0                       The Shawshank Redemption          (1994)
# 1           1                                  The Godfather          (1972)
# 2           2                                The Dark Knight          (2008)
# 3           3  The Lord of the Rings: The Return of the King          (2003)
# 4           4                               Schindler's List          (1993)
#
#   Watch Time  Movie Rating Meatscore of movie   Votes     Gross  \
# 0    142 min           9.3         81          34,709   $28.34M
# 1    175 min           9.2        100          34,709  $134.97M
# 2    152 min           9.0         84          34,709  $534.86M
# 3    201 min           9.0         94          34,709  $377.85M
# 4    195 min           9.0         94          34,709   $96.90M
#
#                                          Description
# 0  Two imprisoned men bond over a number of years...
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Movie Name', 'Year of Release', 'Watch Time',
#        'Movie Rating', 'Meatscore of movie', 'Votes', 'Gross', 'Description'],
#       dtype='object')

# %%
data.tail()
# Out:
#      Unnamed: 0                       Movie Name Year of Release Watch Time  \
# 995         995                          Sabrina          (1954)    113 min
# 996         996            From Here to Eternity          (1953)    118 min
# 997         997  Snow White and the Seven Dwarfs          (1937)     83 min
# 998         998                     The 39 Steps          (1935)     86 min
# 999         999                The Invisible Man          (1933)     71 min
#
#      Movie Rating Meatscore of movie   Votes     Gross  \
# 995           7.6         72          34,709    %^%^%^
# 996           7.6         85          34,709   $30.50M
# 997           7.6         95          34,709  $184.93M
# 998           7.6         93          34,709    %^%^%^
# 999           7.6         87          34,709    %^%^%^
#
#                                            Description
# 995  A playboy becomes interested in the daughter o...
# 996  At a U.S. Army base in 1941 Hawaii, a private ...
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0  Movie Rating
# count  1000.000000   1000.000000
# mean    499.500000      7.962700
# std     288.819436      0.276759
# min       0.000000      7.600000
# 25%     249.750000      7.700000
# 50%     499.500000      7.900000
# 75%     749.250000      8.100000
# max     999.000000      9.300000

# %%
data.isnull().sum()
# Out:
# Unnamed: 0            0
# Movie Name            0
# Year of Release       0
# Watch Time            0
# Movie Rating          0
# Meatscore of movie    0
# Votes                 0
# Gross                 0
# Description           0
# dtype: int64

# %%
data.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0                                     Movie Name  \
# 0             0                       The Shawshank Redemption
# 1             1                                  The Godfather
# 2             2                                The Dark Knight
# 3             3  The Lord of the Rings: The Return of the King
# 4             4                               Schindler's List
# ..          ...                                            ...
# 995         995                                        Sabrina
# 996         996                          From Here to Eternity
# 997         997                Snow White and the Seven Dwarfs
# 998         998                                   The 39 Steps
# 999         999                              The Invisible Man
#
#     Year of Release Watch Time  Movie Rating Meatscore of movie   Votes  \
# 0            (1994)    142 min           9.3         81          34,709
# ...

# %%
data.shape
# Out:
# (1000, 9)

# %% [markdown]
# # Visualization on Data

# %% [markdown]
# # Let's Plot Some Diagrams !!

# %%
sns.lineplot(data = data, x = "Watch Time", y = "Movie Name", ci = None)
# Out:
# <AxesSubplot:xlabel='Watch Time', ylabel='Movie Name'>

# %%
sns.lineplot(data = data, x = "Movie Name", y = "Year of Release", ci = None)
# Out:
# <AxesSubplot:xlabel='Movie Name', ylabel='Year of Release'>

# %%
sns.lineplot(data = data, x = "Meatscore of movie", y = "Movie Name", ci = None)
# Out:
# <AxesSubplot:xlabel='Meatscore of movie', ylabel='Movie Name'>

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Movie Name', 'Year of Release', 'Watch Time',
#        'Movie Rating', 'Meatscore of movie', 'Votes', 'Gross', 'Description'],
#       dtype='object')

# %%
sns.lineplot(data = data, x = "Votes", y = "Gross", ci = None)
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Gross'>

# %%
data['Gross'].value_counts()
# Out:
# %^%^%^      153
# $0.01M        8
# $0.06M        5
# $0.17M        5
# $4.36M        5
#            ...
# $0.45M        1
# $10.90M       1
# $23.65M       1
# $3.27M        1
# $184.93M      1
# Name: Gross, Length: 746, dtype: int64

# %%
plt.figure(figsize = (14,6))
sns.countplot(data = data, x = data['Gross'])
# Out:
# <AxesSubplot:xlabel='Gross', ylabel='count'>

# %%
data.corr()['Movie Rating']
# Out:
# Unnamed: 0     -0.938779
# Movie Rating    1.000000
# Name: Movie Rating, dtype: float64
